# %%
pip install pandas

# %%
import pandas as pd

# %% [markdown]
# Series in pandas (1D)

# %%
s = pd.Series([2,8,7,4,37])

# %%
s
# Out:
# 0     2
# 1     8
# 2     7
# 3     4
# 4    37
# dtype: int64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s[1]
# Out:
# 8

# %%
s2 = pd.Series([2,8,7,4,37], index = ['a','b','c','d','e'])

# %%
s
# Out:
# a     2
# b     8
# c     7
# d     4
# e    37
# dtype: int64

# %%
s2[1]
# Out:
# 8

# %%
s2 = pd.Series([2,8,7,4,37], dtype = 'float')

# %%
s2
# Out:
# 0     2.0
# 1     8.0
# 2     7.0
# 3     4.0
# 4    37.0
# dtype: float64

# %%
s.max()
# Out:
# 37

# %%
s.min()
# Out:
# 2

# %%
s.mean()
# Out:
# 11.6

# %% [markdown]
# DataFrame in pandas (2D) --> Collection of series

# %%
df = pd.DataFrame([[11,22,33,44,55],[55,66,77,88,99],[7,8,9,4,5]])

# %%
df
# Out:
#     0   1   2   3   4
# 0  11  22  33  44  55
# 1  55  66  77  88  99
# 2   7   8   9   4   5

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[0])
# Out:
# pandas.core.series.Series

# %%
df[0]
# Out:
# 0    11
# 1    55
# 2     7
# Name: 0, dtype: int64

# %%
df[1]
# Out:
# 0    22
# 1    66
# 2     8
# Name: 1, dtype: int64

# %%
df[[0]]
# Out:
#     0
# 0  11
# 1  55
# 2   7

# %%
df[0:1]
# Out:
#     0   1   2   3   4
# 0  11  22  33  44  55

# %%
type(df[0:1])
# Out:
# pandas.core.frame.DataFrame

# %%
df[0:2]
# Out:
#     0   1   2   3   4
# 0  11  22  33  44  55
# 1  55  66  77  88  99

# %%
df[:]
# Out:
#     0   1   2   3   4
# 0  11  22  33  44  55
# 1  55  66  77  88  99
# 2   7   8   9   4   5

# %%
df[::2]
# Out:
#     0   1   2   3   4
# 0  11  22  33  44  55
# 2   7   8   9   4   5

# %%
x = pd.Series([1,2,3,4,5])

# %%
x = pd.Series({
    "a":1,
    "b":2,
    "c":3
})

# %%
x
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = pd.DataFrame({
    "name":["aaa","bbb","ccc","ddd","eee","fff","ggg","hhh"],
    "rn":[1,2,3,4,5,6,7,8],
    "sub":["maths","hindi","english","marathi","geo","history","computer","pt"]
})

# %%
data
# Out:
#   name  rn       sub
# 0  aaa   1     maths
# 1  bbb   2     hindi
# 2  ccc   3   english
# 3  ddd   4   marathi
# 4  eee   5       geo
# 5  fff   6   history
# 6  ggg   7  computer
# 7  hhh   8        pt

# %%
df = pd.DataFrame([[11,22,33,44,55],[55,66,77,88,99],[7,8,9,4,5]], columns =["one","two","three","four","4"],index=[11,22,33])

# %%
df
# Out:
#     one  two  three  four   4
# 11   11   22     33    44  55
# 22   55   66     77    88  99
# 33    7    8      9     4   5

# %%
data = pd.DataFrame({
    "name":["aaa","bbb","ccc","ddd","eee","fff","ggg","hhh"],
    "rn":[1,2,3,4,5,6,7,8],
    "sub":["maths","hindi","english","marathi","geo","history","computer","pt"]
})

# %%
data.head(2)
# Out:
#   name  rn    sub
# 0  aaa   1  maths
# 1  bbb   2  hindi

# %%
data.tail(2)
# Out:
#   name  rn       sub
# 6  ggg   7  computer
# 7  hhh   8        pt

# %%
data.max()
# Out:
# name    hhh
# rn        8
# sub      pt
# dtype: object

# %%
data.min()
# Out:
# name         aaa
# rn             1
# sub     computer
# dtype: object

# %%
data.sum()
# Out:
# name                        aaabbbcccdddeeefffggghhh
# rn                                                36
# sub     mathshindienglishmarathigeohistorycomputerpt
# dtype: object

# %%
data["rn"].mean()
# Out:
# 4.5

# %%
print("missing Values of data:")
data.isnull().sum()
# Out:
# missing Values of data
# name    0
# rn      0
# sub     0
# dtype: int64
