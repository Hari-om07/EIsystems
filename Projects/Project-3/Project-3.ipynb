# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Data Science/insurance.csv')

# %%
data.head()
# Out:
#    sr.no  age  bought_insurance
# 0      1   22                 0
# 1      2   25                 0
# 2      3   47                 1
# 3      4   52                 0
# 4      5   46                 1

# %%
data.isnull().sum()
# Out:
# sr.no               0
# age                 0
# bought_insurance    0
# dtype: int64

# %%
#splitting data into dependent and independent variable
x = data[['age']]
y = data.bought_insurance

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x, y, color = 'red')
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings('ignore')

# %%
model = LogisticRegression()

# %%
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
a = int(input("Enter the value of age:"))
if model.predict([[a]])[0]==0:
  print("Insurance will not be getting bought")
else:
  print("Insurance will be bought")
# Out:
# Enter the value of age:14
# Insurance will not  getting bought

# %%
model.predict(x)==y
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16    False
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# Name: bought_insurance, dtype: bool

# %%
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64
