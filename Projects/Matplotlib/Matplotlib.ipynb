# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
days = [1,2,3,4,5,6,7]
likes = [190,250,457,564,896,471,899]

# %%
plt.title("My Facebook likes")
plt.xlabel("Number of Days")
plt.ylabel("Number of likes")
plt.plot(days,likes,color = "red", marker = "o", mfc = "blue", mec = "yellow", mew = 3, ms = 15, ls = "--", lw = 5, fillstyle = "full")
plt.grid(color = "green")
plt.xlim(3,5)
plt.ylim(300,600)
plt.show()

# %% [markdown]
# Comparing different social media using matplotlib

# %%
days
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
fb = likes.copy()
insta = [210,178,266,712,456,45,812]
ytube = [971,450,489,210,567,495,536]

# %%
fb
insta
ytube
# Out:
# [971, 450, 489, 210, 567, 495, 536]

# %%
plt.title("Social Media Analyzation")
plt.xlabel("No. of Days")
plt.ylabel("No. of likes")
plt.plot(days,fb, label = "fbook", color = "blue", marker = "o", ms = 10, mfc = "yellow", )
plt.plot(days,insta, label = "insta", color = "m", marker = "s", ms = 10, mfc = "pink")
plt.plot(days,ytube, label = "ytube", color = "red", marker = ">", ms = 10, mfc = "black")
plt.legend(loc = "upper center")
plt.grid(color ="orange")
#plt.xlim(3,5)
#plt.ylim(500,600)
plt.savefig("mygraph.png")
plt.show()

# %% [markdown]
# Different types of graph

# %% [markdown]
# Scatterplot

# %%
days
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
likes
# Out:
# [190, 250, 457, 564, 896, 471, 899]

# %%
plt.scatter(days,likes,color = "red", ec = "yellow", s = 100, alpha = 1, )
plt.show()

# %%
plt.scatter(days,likes, ec = "green", s = 100, cmap = "Blues", c = [111,2,3,4,5,6,7])
plt.show()

# %% [markdown]
# Bar plot

# %%
days
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
likes
# Out:
# [190, 250, 457, 564, 896, 471, 899]

# %%
plt.bar(days,likes, color = ["red","yellow","green","blue","m","orange", "cyan"],align = "edge", tick_label = likes )
plt.show()

# %% [markdown]
# pie

# %%
likes = [250,190,470,550,390]
p = ["insta","fb","sc","ln","yt"]

# %%
plt.pie(likes, labels = p, colors = ["pink", "yellow", "cyan", "red"], autopct = "%1.1f", shadow = True, explode = [0.2,0.3,0,0,0], radius = 1)
plt.show()

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
plt.scatter(data.housing_median_age,data.population, color = "red")
plt.show()
